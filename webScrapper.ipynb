# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeWithShivram/2048-Game/blob/main/webScrapper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

class Scraper:
    def __init__(self, site):
        self.site = site

    def scrape(self):
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
        }

        try:
            response = requests.get(self.site, headers=headers)
            response.raise_for_status()  # Raise an error for bad responses
            html = response.text
            parser = "html.parser"
            sp = BeautifulSoup(html, parser)

            found_links = False  # Track if we found any relevant links

            for tag in sp.find_all("a"):
                url = tag.get("href")
                if url and "articles" in url:
                    print("\n" + url)
                    found_links = True

            if not found_links:
                print("No article links found.")

        except requests.exceptions.HTTPError as e:
            print(f"HTTP error occurred: {e.response.status_code}")
        except requests.exceptions.RequestException as e:
            print(f"Request error occurred: {e}")

news = "https://www.bbc.com/news"
Scraper(news).scrape()
# Out:
# /news/articles/c70zn97q1n8o
#
# /news/articles/cly3gz35dgro
#
# /news/articles/c7810y11dyjo
#
# /news/articles/cz04depp2nro
#
# /news/articles/ce3zq40qq25o
#
# /news/articles/ckgvr9kgkqyo
#
# /news/articles/c70zn97q1n8o
#
# /news/articles/cy89ez894rko
#
# /news/articles/cvglvy6gn54o
#
# /news/articles/cyvym5g02rdo
#
# /news/articles/cgeyg2vgdz0o
#
# /news/articles/cm246p3npdqo
#
# /news/articles/cwylnl02em1o
#
# /news/articles/c2439n8mr31o
#
# /news/articles/cj4x71znwxdo
#
# /news/articles/cglkenxgd5xo
#
# /news/articles/crm2k04m2gxo
#
# /news/articles/c9wklzkey8ro
#
# /news/articles/cly3gz35dgro
#
# /news/articles/c98ype90313o
#
# /news/articles/crm2k04m2gxo
#
# /news/articles/ckg9qjkgqxgo
#
# /news/articles/c9wklzkey8ro
#
# /news/articles/cz9py388z17o
#
# /news/articles/cgeyg2g288wo
#
# /news/articles/cr5482yygp4o
#
# /news/articles/c756d56d2dro
#
# /news/articles/c6258zn1663o
#
# /news/articles/cgeyg2g288wo
#
# /news/articles/c5y9x6zrkrro
#
# /news/articles/c5yjej0rvw0o
#
# ...
